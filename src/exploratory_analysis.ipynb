# %%
import pandas as pd

# %%
df = pd.read_csv(
    "raw_data/dc-candidates-scotland-2026-04-02T16-17-27.csv"
)

df.head()
# Out:
#    person_id         person_name      election_id  \
# 0      21107         Jenny Laing  sp.c.2026-05-07
# 1     123268      Jack Middleton  sp.c.2026-05-07
# 2      85485  Yi-Pei Chou Turvey  sp.c.2026-05-07
# 3       1411       Stewart Whyte  sp.c.2026-05-07
# 4     125804        James Wyllie  sp.c.2026-05-07
#
#                     ballot_paper_id election_date election_current  \
# 0  sp.c.aberdeen-central.2026-05-07    2026-05-07                t
# 1  sp.c.aberdeen-central.2026-05-07    2026-05-07                t
# 2  sp.c.aberdeen-central.2026-05-07    2026-05-07                t
# 3  sp.c.aberdeen-central.2026-05-07    2026-05-07                t
# 4  sp.c.aberdeen-central.2026-05-07    2026-05-07                t
#
#                         party_name party_id        post_label cancelled_poll  \
# 0                     Labour Party     PP53  Aberdeen Central              f
# 1    Scottish National Party (SNP)    PP102  Aberdeen Central              f
# ...
